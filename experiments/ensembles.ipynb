# %%
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pickle

import numpy as np
from model.ensemble import MLPEnsemble
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold 
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

from dataloader.builder import build_dataset
from model.mlp import MLP
from uncertainty_estimator.masks import build_masks 
from experiment_setup import build_estimator
from analysis.metrics import get_uq_metrics

plt.rcParams['figure.facecolor'] = 'white'

# %%
config = {
    'random_seed': 43,
    'nn_runs': 100,
    'runs': 2,
    'max_runs': 20,
    'k_folds': 10,
    'verbose': False,
    'use_cache': False,
    'layers': [8, 256, 256, 128, 1],
    'epochs': 5_000,
    'validation_step': 100,
    'acc_percentile': 0.1,
    'patience': 5,
    'dropout_train': 0.2,
    'dropout_uq': 0.5,
    'batch_size': 512,
    'dataset': 'kin8nm',
    'scale': True,
    'l2_reg': 1e-5
}

# %%
# Get data
dataset = build_dataset(config['dataset']) 
x_set, y_set = dataset.dataset('train')
x_test, y_test = dataset.dataset('val')
config['layers'][0] = x_set.shape[-1]

# %%
# Helper functions
def scale(train, val):
    scaler = StandardScaler()
    scaler.fit(train)
    train = scaler.transform(train)
    val = scaler.transform(val)
    return train, val, scaler


def plot_evaluations(model, x, y, x_, y_):
    plt.figure(figsize=(10, 10))
    plt.plot((min(y), max(y)), (min(y), max(y)))
    plt.scatter(model(x).cpu().numpy(), y)
    plt.scatter(model(x_).cpu().numpy(), y_)
    plt.show()

# Evaluate different masks
def evaluate_masks(model, masks, x_val, y_val, y_scaler):
    predictions = model(x_val).cpu().numpy()
    errors = np.abs(predictions - y_val)
    scaled_errors = y_scaler.inverse_transform(predictions) - y_scaler.inverse_transform(y_val)
    rmse = np.sqrt(np.mean(np.square(scaled_errors)))
    results = []

    for name, mask in masks.items():
        estimator = build_estimator(
            'mcdue_masked', model, nn_runs=config['nn_runs'], dropout_mask=mask,
            dropout_rate=config['dropout_uq'])

        for run in range(config['runs']):
            estimations = estimator.estimate(x_val)
            acc, ndcg, nll = get_uq_metrics(estimations, errors, config['acc_percentile'])
            results.append([acc, ndcg, nll, rmse, name])

            if hasattr(mask, 'reset'):
                mask.reset()

    return results

# %%
def multiple_kfold(k, data_size, max_iterations):
    kfold = KFold(k)
    for i in range(max_iterations):
        if i % k == 0:
            data_idx = np.random.permutation(data_size)
            idx_generator = kfold.split(data_idx)
        train_idx, val_idx = next(idx_generator)
        yield data_idx[train_idx], data_idx[val_idx]

# %%
mask_results = [] 
masks = build_masks(['vanilla', 'mirror_random', 'decorrelating', 'dpp'], nn_runs=config['nn_runs'])

kfold_iterator = multiple_kfold(config['k_folds'], len(x_set), config['max_runs'])
for m, (train_idx, val_idx) in enumerate(kfold_iterator):
    x_train, y_train = x_set[train_idx], y_set[train_idx]
    x_val, y_val = x_set[val_idx], y_set[val_idx]
    print("Model", m+1)

    if config['scale']:
        x_train, x_val, _ = scale(x_train, x_val)
        y_train, y_val, y_scaler = scale(y_train, y_val)
    else:
        y_scaler = None
        
    train_opts = ['patience', 'dropout_rate', 'epochs', 'batch_size', 'validation_step']
    train_config = {k: config[k] for k in config if k in train_opts}
    
    model = MLP(config['layers'], l2_reg=config['l2_reg'])
    model.fit((x_train, y_train), (x_val, y_val), **train_config)
    if config['verbose']:
        plot_evaluations(model, x_train, y_train, x_val, y_val)
    
    
    results = evaluate_masks(model, masks, x_val, y_val, y_scaler)
    mask_results.extend(results)
    
    model = MLPEnsemble(config['layers'], 10)
    model.fit((x_train, y_train), (x_val, y_val), **train_config)
    predictions = model(x_val).cpu().numpy()
    errors = np.abs(predictions - y_val)
    scaled_errors = y_scaler.inverse_transform(predictions) - y_scaler.inverse_transform(y_val)
    rmse = np.sqrt(np.mean(np.square(scaled_errors)))
    
    uncertainty = model.compute_uncertainty(x_val).cpu().numpy()
    acc, ndcg, nll = get_uq_metrics(uncertainty, errors, config['acc_percentile'])
    mask_results.append([acc, ndcg, nll, rmse, 'ensemble'])
    
    
    uncertainty = model.compute_uncertainty(x_val, dropout_rate=config['dropout_uq'], repeat=config['nn_runs']).cpu().numpy()
    acc, ndcg, nll = get_uq_metrics(uncertainty, errors, config['acc_percentile'])
    mask_results.append([acc, ndcg, nll, rmse, 'drop_ensemble'])
# Out:
# Model 1
# Epoch [100/5000], Loss: 0.0462, Validation loss: 0.0841
# Epoch [200/5000], Loss: 0.0416, Validation loss: 0.0969
# Epoch [300/5000], Loss: 0.0263, Validation loss: 0.0875
# Epoch [400/5000], Loss: 0.0188, Validation loss: 0.0830
# Epoch [500/5000], Loss: 0.0152, Validation loss: 0.0814
# Epoch [600/5000], Loss: 0.0153, Validation loss: 0.0899
# Epoch [700/5000], Loss: 0.0150, Validation loss: 0.0960
# Epoch [800/5000], Loss: 0.0092, Validation loss: 0.0896
# Epoch [900/5000], Loss: 0.0112, Validation loss: 0.0903
# Epoch [1000/5000], Loss: 0.0062, Validation loss: 0.0861
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 2
# Epoch [100/5000], Loss: 0.0740, Validation loss: 0.0997
# Epoch [200/5000], Loss: 0.0436, Validation loss: 0.0960
# Epoch [300/5000], Loss: 0.0304, Validation loss: 0.0857
# Epoch [400/5000], Loss: 0.0148, Validation loss: 0.0814
# Epoch [500/5000], Loss: 0.0232, Validation loss: 0.0989
# Epoch [600/5000], Loss: 0.0152, Validation loss: 0.0828
# Epoch [700/5000], Loss: 0.0116, Validation loss: 0.0895
# Epoch [800/5000], Loss: 0.0107, Validation loss: 0.0875
# Epoch [900/5000], Loss: 0.0082, Validation loss: 0.0875
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 3
# Epoch [100/5000], Loss: 0.0612, Validation loss: 0.0934
# Epoch [200/5000], Loss: 0.0307, Validation loss: 0.0725
# Epoch [300/5000], Loss: 0.0211, Validation loss: 0.0705
# Epoch [400/5000], Loss: 0.0176, Validation loss: 0.0845
# Epoch [500/5000], Loss: 0.0123, Validation loss: 0.0744
# Epoch [600/5000], Loss: 0.0161, Validation loss: 0.0807
# Epoch [700/5000], Loss: 0.0143, Validation loss: 0.0810
# Epoch [800/5000], Loss: 0.0086, Validation loss: 0.0788
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 4
# Epoch [100/5000], Loss: 0.0606, Validation loss: 0.1044
# Epoch [200/5000], Loss: 0.0349, Validation loss: 0.0884
# Epoch [300/5000], Loss: 0.0224, Validation loss: 0.0961
# Epoch [400/5000], Loss: 0.0171, Validation loss: 0.0897
# Epoch [500/5000], Loss: 0.0135, Validation loss: 0.0890
# Epoch [600/5000], Loss: 0.0156, Validation loss: 0.0905
# Epoch [700/5000], Loss: 0.0058, Validation loss: 0.0890
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 5
# Epoch [100/5000], Loss: 0.0587, Validation loss: 0.1058
# Epoch [200/5000], Loss: 0.0279, Validation loss: 0.0687
# Epoch [300/5000], Loss: 0.0274, Validation loss: 0.0793
# Epoch [400/5000], Loss: 0.0260, Validation loss: 0.0821
# Epoch [500/5000], Loss: 0.0210, Validation loss: 0.0969
# Epoch [600/5000], Loss: 0.0131, Validation loss: 0.0784
# Epoch [700/5000], Loss: 0.0120, Validation loss: 0.0841
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 6
# Epoch [100/5000], Loss: 0.0792, Validation loss: 0.0908
# Epoch [200/5000], Loss: 0.0393, Validation loss: 0.0941
# Epoch [300/5000], Loss: 0.0256, Validation loss: 0.0960
# Epoch [400/5000], Loss: 0.0175, Validation loss: 0.0997
# Epoch [500/5000], Loss: 0.0119, Validation loss: 0.0896
# Epoch [600/5000], Loss: 0.0072, Validation loss: 0.0861
# Epoch [700/5000], Loss: 0.0111, Validation loss: 0.0934
# Epoch [800/5000], Loss: 0.0064, Validation loss: 0.0906
# Epoch [900/5000], Loss: 0.0102, Validation loss: 0.1015
# Epoch [1000/5000], Loss: 0.0066, Validation loss: 0.0952
# Epoch [1100/5000], Loss: 0.0066, Validation loss: 0.0909
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 7
# Epoch [100/5000], Loss: 0.0407, Validation loss: 0.0903
# Epoch [200/5000], Loss: 0.0310, Validation loss: 0.0927
# Epoch [300/5000], Loss: 0.0166, Validation loss: 0.0847
# Epoch [400/5000], Loss: 0.0218, Validation loss: 0.1004
# Epoch [500/5000], Loss: 0.0189, Validation loss: 0.1044
# Epoch [600/5000], Loss: 0.0143, Validation loss: 0.0948
# Epoch [700/5000], Loss: 0.0067, Validation loss: 0.0919
# Epoch [800/5000], Loss: 0.0156, Validation loss: 0.0954
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 8
# Epoch [100/5000], Loss: 0.0770, Validation loss: 0.1463
# Epoch [200/5000], Loss: 0.0353, Validation loss: 0.0801
# Epoch [300/5000], Loss: 0.0308, Validation loss: 0.0940
# Epoch [400/5000], Loss: 0.0204, Validation loss: 0.0942
# Epoch [500/5000], Loss: 0.0207, Validation loss: 0.0965
# Epoch [600/5000], Loss: 0.0118, Validation loss: 0.0934
# Epoch [700/5000], Loss: 0.0093, Validation loss: 0.0956
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 9
# Epoch [100/5000], Loss: 0.0533, Validation loss: 0.0954
# Epoch [200/5000], Loss: 0.0316, Validation loss: 0.0783
# Epoch [300/5000], Loss: 0.0232, Validation loss: 0.0814
# Epoch [400/5000], Loss: 0.0206, Validation loss: 0.0929
# Epoch [500/5000], Loss: 0.0161, Validation loss: 0.0822
# Epoch [600/5000], Loss: 0.0151, Validation loss: 0.0920
# Epoch [700/5000], Loss: 0.0067, Validation loss: 0.0819
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 10
# Epoch [100/5000], Loss: 0.0615, Validation loss: 0.0854
# Epoch [200/5000], Loss: 0.0381, Validation loss: 0.0812
# Epoch [300/5000], Loss: 0.0203, Validation loss: 0.0775
# Epoch [400/5000], Loss: 0.0181, Validation loss: 0.0818
# Epoch [500/5000], Loss: 0.0145, Validation loss: 0.0944
# Epoch [600/5000], Loss: 0.0176, Validation loss: 0.1079
# Epoch [700/5000], Loss: 0.0100, Validation loss: 0.0929
# Epoch [800/5000], Loss: 0.0076, Validation loss: 0.0907
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 11
# Epoch [100/5000], Loss: 0.0647, Validation loss: 0.0864
# Epoch [200/5000], Loss: 0.0405, Validation loss: 0.0873
# Epoch [300/5000], Loss: 0.0268, Validation loss: 0.0882
# Epoch [400/5000], Loss: 0.0147, Validation loss: 0.0837
# Epoch [500/5000], Loss: 0.0208, Validation loss: 0.0876
# Epoch [600/5000], Loss: 0.0084, Validation loss: 0.0844
# Epoch [700/5000], Loss: 0.0133, Validation loss: 0.0944
# Epoch [800/5000], Loss: 0.0076, Validation loss: 0.0866
# Epoch [900/5000], Loss: 0.0110, Validation loss: 0.0945
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 12
# Epoch [100/5000], Loss: 0.0874, Validation loss: 0.1060
# Epoch [200/5000], Loss: 0.0277, Validation loss: 0.0840
# Epoch [300/5000], Loss: 0.0323, Validation loss: 0.0873
# Epoch [400/5000], Loss: 0.0178, Validation loss: 0.0814
# Epoch [500/5000], Loss: 0.0147, Validation loss: 0.0861
# Epoch [600/5000], Loss: 0.0073, Validation loss: 0.0778
# Epoch [700/5000], Loss: 0.0071, Validation loss: 0.0794
# Epoch [800/5000], Loss: 0.0128, Validation loss: 0.0958
# Epoch [900/5000], Loss: 0.0092, Validation loss: 0.0872
# Epoch [1000/5000], Loss: 0.0110, Validation loss: 0.0885
# Epoch [1100/5000], Loss: 0.0062, Validation loss: 0.0839
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 13
# Epoch [100/5000], Loss: 0.0596, Validation loss: 0.0722
# Epoch [200/5000], Loss: 0.0351, Validation loss: 0.0822
# Epoch [300/5000], Loss: 0.0294, Validation loss: 0.0849
# Epoch [400/5000], Loss: 0.0169, Validation loss: 0.0764
# Epoch [500/5000], Loss: 0.0127, Validation loss: 0.0768
# Epoch [600/5000], Loss: 0.0141, Validation loss: 0.0788
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 14
# Epoch [100/5000], Loss: 0.0644, Validation loss: 0.1150
# Epoch [200/5000], Loss: 0.0397, Validation loss: 0.0853
# Epoch [300/5000], Loss: 0.0268, Validation loss: 0.0891
# Epoch [400/5000], Loss: 0.0266, Validation loss: 0.0914
# Epoch [500/5000], Loss: 0.0182, Validation loss: 0.0925
# Epoch [600/5000], Loss: 0.0197, Validation loss: 0.0962
# Epoch [700/5000], Loss: 0.0092, Validation loss: 0.0813
# Epoch [800/5000], Loss: 0.0099, Validation loss: 0.0845
# Epoch [900/5000], Loss: 0.0089, Validation loss: 0.0859
# Epoch [1000/5000], Loss: 0.0091, Validation loss: 0.0891
# Epoch [1100/5000], Loss: 0.0050, Validation loss: 0.0824
# Epoch [1200/5000], Loss: 0.0072, Validation loss: 0.0850
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 15
# Epoch [100/5000], Loss: 0.0710, Validation loss: 0.0939
# Epoch [200/5000], Loss: 0.0429, Validation loss: 0.0767
# Epoch [300/5000], Loss: 0.0273, Validation loss: 0.0759
# Epoch [400/5000], Loss: 0.0185, Validation loss: 0.0759
# Epoch [500/5000], Loss: 0.0219, Validation loss: 0.0806
# Epoch [600/5000], Loss: 0.0159, Validation loss: 0.0819
# Epoch [700/5000], Loss: 0.0129, Validation loss: 0.0827
# Epoch [800/5000], Loss: 0.0113, Validation loss: 0.0815
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 16
# Epoch [100/5000], Loss: 0.0590, Validation loss: 0.1011
# Epoch [200/5000], Loss: 0.0437, Validation loss: 0.1024
# Epoch [300/5000], Loss: 0.0286, Validation loss: 0.0918
# Epoch [400/5000], Loss: 0.0151, Validation loss: 0.0847
# Epoch [500/5000], Loss: 0.0227, Validation loss: 0.0987
# Epoch [600/5000], Loss: 0.0169, Validation loss: 0.0958
# Epoch [700/5000], Loss: 0.0110, Validation loss: 0.0918
# Epoch [800/5000], Loss: 0.0079, Validation loss: 0.0899
# Epoch [900/5000], Loss: 0.0106, Validation loss: 0.0917
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:
# Fit [8/10] model:
# Fit [9/10] model:
# Model 17
# Epoch [100/5000], Loss: 0.0547, Validation loss: 0.0943
# Epoch [200/5000], Loss: 0.0476, Validation loss: 0.1119
# Epoch [300/5000], Loss: 0.0322, Validation loss: 0.1046
# Epoch [400/5000], Loss: 0.0251, Validation loss: 0.1032
# Epoch [500/5000], Loss: 0.0147, Validation loss: 0.0880
# Epoch [600/5000], Loss: 0.0079, Validation loss: 0.0858
# Epoch [700/5000], Loss: 0.0075, Validation loss: 0.0942
# Epoch [800/5000], Loss: 0.0084, Validation loss: 0.0923
# Epoch [900/5000], Loss: 0.0090, Validation loss: 0.0939
# Epoch [1000/5000], Loss: 0.0053, Validation loss: 0.0933
# Epoch [1100/5000], Loss: 0.0063, Validation loss: 0.0898
# Fit [0/10] model:
# Fit [1/10] model:
# Fit [2/10] model:
# Fit [3/10] model:
# Fit [4/10] model:
# Fit [5/10] model:
# Fit [6/10] model:
# Fit [7/10] model:

# %%
uncertainty = model.compute_uncertainty(x_val, repeat=1).cpu().numpy()
plt.scatter(errors, uncertainty)
uncertainty = model.compute_uncertainty(x_val, repeat=100, dropout_rate=0.5).cpu().numpy()
plt.scatter(errors, uncertainty)

# %%
# # Plot the results
mask_df = pd.DataFrame(mask_results, columns=['acc', 'ndcg', 'nll', 'rmse', 'mask'])

fig = plt.figure(figsize=(16, 16))
plt.suptitle(config['dataset'], fontsize=16)
fig.subplots_adjust(top=0.95)


def boxplot(df, x_label, y_label, i, bottom=0, top=1):
    plt.subplot(2, 2, i)
    plt.xticks(rotation=45)
    if bottom is not None:
        plt.ylim(bottom, top)
    sns.boxplot(data=df, x=x_label, y=y_label)

boxplot(mask_df, 'mask', 'acc', 1, 0, 0.8)
boxplot(mask_df, 'mask', 'ndcg', 2, 0, 0.9)
boxplot(mask_df, 'mask', 'nll', 3, None)
boxplot(mask_df, None, 'rmse', 4, 0, 1.2*mask_df.rmse.max())

# %%
with open(f"data/results_{config['dataset']}.pkl", 'wb') as f:
    pickle.dump(mask_results, f)

# %%
predictions = model(x_val).cpu().numpy()

# %%
import socket
print(socket.gethostname())

# %%
class Foo(object):
     def __init__(self, frob, frotz):
          self.frobnicate = frob
          self.frotz = frotz

class Bar(Foo):
     def __init__(self, frob, frizzle):
          # super(Bar, self).__init__(frob, frizzle)
          super().__init__(frob, frizzle)
          self.frotz = 34
          self.frazzle = frizzle


bar = Bar(1,2)
print("frobnicate:", bar.frobnicate)
print("frotz:", bar.frotz)
print("frazzle:", bar.frazzle)
# Out:
# frobnicate: 1
# frotz: 34
# frazzle: 2
